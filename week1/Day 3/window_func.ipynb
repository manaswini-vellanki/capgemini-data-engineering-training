-- %%
CREATE OR REPLACE TABLE employees (
    emp_id INT,
    emp_name VARCHAR(50),
    department VARCHAR(50),
    salary INT,
    join_date DATE
);

INSERT INTO employees  VALUES
(1, 'Amit', 'Chennai', 2000, '2023-01-01'),
(2, 'Ravi', 'Hyderabad', 1500, '2023-01-02'),
(3, 'Sneha', 'Chennai', 3000, '2023-01-03'),
(4, 'Kiran', 'Bangalore', 2500, '2023-01-04'),
(5, 'Priya', 'Chennai', 2000, '2023-01-05'),
(6, 'Arjun', 'Hyderabad', 1800, '2023-01-06'),
(7, 'Neha', 'Bangalore', 2200, '2023-01-07'),
(8, 'Vikas', 'Chennai', 3000, '2023-01-08'),
(9, 'Anjali', 'Hyderabad', 1700, '2023-01-09'),
(10, 'Rahul', 'Bangalore', 2600, '2023-01-10'),
(11, 'Suresh', 'Chennai', 2800, '2023-01-11'),
(12, 'Pooja', 'Hyderabad', 1600, '2023-01-12'),
(13, 'Manoj', 'Bangalore', 2400, '2023-01-13'),
(14, 'Divya', 'Chennai', 2100, '2023-01-14'),
(15, 'Karthik', 'Hyderabad', 1900, '2023-01-15'),
(16, 'Meena', 'Bangalore', 2300, '2023-01-16'),
(17, 'Raj', 'Chennai', 2700, '2023-01-17'),
(18, 'Simran', 'Hyderabad', 2000, '2023-01-18'),
(19, 'Deepak', 'Bangalore', 2500, '2023-01-19'),
(20, 'Nisha', 'Chennai', 2600, '2023-01-20');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>20</td><td>20</td></tr></tbody></table></div>

-- %% [markdown]
-- ## ROW_NUMBER()

-- %%
--Assign a unique row number to all employees based on salary (highest first). 


select emp_name,salary,
row_number() over(order by salary desc) as row_num
from employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary</th><th>row_num</th></tr></thead><tbody><tr><td>Vikas</td><td>3000</td><td>1</td></tr><tr><td>Sneha</td><td>3000</td><td>2</td></tr><tr><td>Suresh</td><td>2800</td><td>3</td></tr><tr><td>Raj</td><td>2700</td><td>4</td></tr><tr><td>Nisha</td><td>2600</td><td>5</td></tr><tr><td>Rahul</td><td>2600</td><td>6</td></tr><tr><td>Kiran</td><td>2500</td><td>7</td></tr><tr><td>Deepak</td><td>2500</td><td>8</td></tr><tr><td>Manoj</td><td>2400</td><td>9</td></tr><tr><td>Meena</td><td>2300</td><td>10</td></tr><tr><td>Neha</td><td>2200</td><td>11</td></tr><tr><td>Divya</td><td>2100</td><td>12</td></tr><tr><td>Amit</td><td>2000</td><td>13</td></tr><tr><td>Priya</td><td>2000</td><td>14</td></tr><tr><td>Simran</td><td>2000</td><td>15</td></tr><tr><td>Karthik</td><td>1900</td><td>16</td></tr><tr><td>Arjun</td><td>1800</td><td>17</td></tr><tr><td>Anjali</td><td>1700</td><td>18</td></tr><tr><td>Pooja</td><td>1600</td><td>19</td></tr><tr><td>Ravi</td><td>1500</td><td>20</td></tr></tbody></table></div>

-- %%
--2.	Assign row numbers to employees within each department based on salary descending
select emp_name,department,salary,
row_number() over(partition by department order by salary desc)
from employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>department</th><th>salary</th><th>row_number()OVER(PARTITIONBYdepartmentORDERBYsalaryDESC)</th></tr></thead><tbody><tr><td>Rahul</td><td>Bangalore</td><td>2600</td><td>1</td></tr><tr><td>Kiran</td><td>Bangalore</td><td>2500</td><td>2</td></tr><tr><td>Deepak</td><td>Bangalore</td><td>2500</td><td>3</td></tr><tr><td>Manoj</td><td>Bangalore</td><td>2400</td><td>4</td></tr><tr><td>Meena</td><td>Bangalore</td><td>2300</td><td>5</td></tr><tr><td>Neha</td><td>Bangalore</td><td>2200</td><td>6</td></tr><tr><td>Sneha</td><td>Chennai</td><td>3000</td><td>1</td></tr><tr><td>Vikas</td><td>Chennai</td><td>3000</td><td>2</td></tr><tr><td>Suresh</td><td>Chennai</td><td>2800</td><td>3</td></tr><tr><td>Raj</td><td>Chennai</td><td>2700</td><td>4</td></tr><tr><td>Nisha</td><td>Chennai</td><td>2600</td><td>5</td></tr><tr><td>Divya</td><td>Chennai</td><td>2100</td><td>6</td></tr><tr><td>Amit</td><td>Chennai</td><td>2000</td><td>7</td></tr><tr><td>Priya</td><td>Chennai</td><td>2000</td><td>8</td></tr><tr><td>Simran</td><td>Hyderabad</td><td>2000</td><td>1</td></tr><tr><td>Karthik</td><td>Hyderabad</td><td>1900</td><td>2</td></tr><tr><td>Arjun</td><td>Hyderabad</td><td>1800</td><td>3</td></tr><tr><td>Anjali</td><td>Hyderabad</td><td>1700</td><td>4</td></tr><tr><td>Pooja</td><td>Hyderabad</td><td>1600</td><td>5</td></tr><tr><td>Ravi</td><td>Hyderabad</td><td>1500</td><td>6</td></tr></tbody></table></div>

-- %%
--3.	Assign row numbers based on employee joining date (latest first). 

select emp_name,join_date,
row_number() over(order by join_date desc)
from employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th
></tr><tr><td>Priya</td><td>2000</td><td>13</td></tr><tr><td>Simran</td><td>2000</td><td>13</td></tr><tr><td>Karthik</td><td>1900</td><td>16</td></tr><tr><td>Arjun</td><td>1800</td><td>17</td></tr><tr><td>Anjali</td><td>1700</td><td>18</td></tr><tr><td>Pooja</td><td>1600</td><td>19</td></tr><tr><td>Ravi</td><td>1500</td><td>20</td></tr></tbody></table></div>

-- %%
-- 10. Rank employees within each department based on salary (highest first)
SELECT 
    emp_name,
    department,
    salary,
    RANK() OVER (
        PARTITION BY department 
        ORDER BY salary DESC
    ) AS rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>department</th><th>salary</th><th>rank_num</th></tr></thead><tbody><tr><td>Rahul</td><td>Bangalore</td><td>2600</td><td>1</td></tr><tr><td>Kiran</td><td>Bangalore</td><td>2500</td><td>2</td></tr><tr><td>Deepak</td><td>Bangalore</td><td>2500</td><td>2</td></tr><tr><td>Manoj</td><td>Bangalore</td><td>2400</td><td>4</td></tr><tr><td>Meena</td><td>Bangalore</td><td>2300</td><td>5</td></tr><tr><td>Neha</td><td>Bangalore</td><td>2200</td><td>6</td></tr><tr><td>Sneha</td><td>Chennai</td><td>3000</td><td>1</td></tr><tr><td>Vikas</td><td>Chennai</td><td>3000</td><td>1</td></tr><tr><td>Suresh</td><td>Chennai</td><td>2800</td><td>3</td></tr><tr><td>Raj</td><td>Chennai</td><td>2700</td><td>4</td></tr><tr><td>Nisha</td><td>Chennai</td><td>2600</td><td>5</td></tr><tr><td>Divya</td><td>Chennai</td><td>2100</td><td>6</td></tr><tr><td>Amit</td><td>Chennai</td><td>2000</td><td>7</td></tr><tr><td>Priya</td><td>Chennai</td><td>2000</td><td>7</td></tr><tr><td>Simran</td><td>Hyderabad</td><td>2000</td><td>1</td></tr><tr><td>Karthik</td><td>Hyderabad</td><td>1900</td><td>2</td></tr><tr><td>Arjun</td><td>Hyderabad</td><td>1800</td><td>3</td></tr><tr><td>Anjali</td><td>Hyderabad</td><td>1700</td><td>4</td></tr><tr><td>Pooja</td><td>Hyderabad</td><td>1600</td><td>5</td></tr><tr><td>Ravi</td><td>Hyderabad</td><td>1500</td><td>6</td></tr></tbody></table></div>

-- %%
-- 11. Rank employees based on joining date (latest gets rank 1)
SELECT 
    emp_name,
    join_date,
    RANK() OVER (
        ORDER BY join_date DESC
    ) AS rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>join_date</th><th>rank_num</th></tr></thead><tbody><tr><td>Nisha</td><td>2023-01-20</td><td>1</td></tr><tr><td>Deepak</td><td>2023-01-19</td><td>2</td></tr><tr><td>Simran</td><td>2023-01-18</td><td>3</td></tr><tr><td>Raj</td><td>2023-01-17</td><td>4</td></tr><tr><td>Meena</td><td>2023-01-16</td><td>5</td></tr><tr><td>Karthik</td><td>2023-01-15</td><td>6</td></tr><tr><td>Divya</td><td>2023-01-14</td><td>7</td></tr><tr><td>Manoj</td><td>2023-01-13</td><td>8</td></tr><tr><td>Pooja</td><td>2023-01-12</td><td>9</td></tr><tr><td>Suresh</td><td>2023-01-11</td><td>10</td></tr><tr><td>Rahul</td><td>2023-01-10</td><td>11</td></tr><tr><td>Anjali</td><td>2023-01-09</td><td>12</td></tr><tr><td>Vikas</td><td>2023-01-08</td><td>13</td></tr><tr><td>Neha</td><td>2023-01-07</td><td>14</td></tr><tr><td>Arjun</td><td>2023-01-06</td><td>15</td></tr><tr><td>Priya</td><td>2023-01-05</td><td>16</td></tr><tr><td>Kiran</td><td>2023-01-04</td><td>17</td></tr><tr><td>Sneha</td><td>2023-01-03</td><td>18</td></tr><tr><td>Ravi</td><td>2023-01-02</td><td>19</td></tr><tr><td>Amit</td><td>2023-01-01</td><td>20</td></tr></tbody></table></div>

-- %%
-- 12. Rank orders based on order amount (highest first)
SELECT 
    emp_name,
    salary AS order_amount,
    RANK() OVER (
        ORDER BY salary DESC
    ) AS rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>order_amount</th><th>rank_num</th></tr></thead><tbody><tr><td>Vikas</td><td>3000</td><td>1</td></tr><tr><td>Sneha</td><td>3000</td><td>1</td></tr><tr><td>Suresh</td><td>2800</td><td>3</td></tr><tr><td>Raj</td><td>2700</td><td>4</td></tr><tr><td>Nisha</td><td>2600</td><td>5</td></tr><tr><td>Rahul</td><td>2600</td><td>5</td></tr><tr><td>Kiran</td><td>2500</td><td>7</td></tr><tr><td>Deepak</td><td>2500</td><td>7</td></tr><tr><td>Manoj</td><td>2400</td><td>9</td></tr><tr><td>Meena</td><td>2300</td><td>10</td></tr><tr><td>Neha</td><td>2200</td><td>11</td></tr><tr><td>Divya</td><td>2100</td><td>12</td></tr><tr><td>Amit</td><td>2000</td><td>13</td></tr><tr><td>Priya</td><td>2000</td><td>13</td></tr><tr><td>Simran</td><td>2000</td><td>13</td></tr><tr><td>Karthik</td><td>1900</td><td>16</td></tr><tr><td>Arjun</td><td>1800</td><td>17</td></tr><tr><td>Anjali</td><td>1700</td><td>18</td></tr><tr><td>Pooja</td><td>1600</td><td>19</td></tr><tr><td>Ravi</td><td>1500</td><td>20</td></tr></tbody></table></div>

-- %%
-- 13. Rank orders within each city based on order amount (highest first)
SELECT 
    emp_name,
    department AS city,
    salary AS order_amount,
    RANK() OVER (
        PARTITION BY department
        ORDER BY salary DESC
    ) AS rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>city</th><th>order_amount</th><th>rank_num</th></tr></thead><tbody><tr><td>Rahul</td><td>Bangalore</td><td>2600</td><td>1</td></tr><tr><td>Kiran</td><td>Bangalore</td><td>2500</td><td>2</td></tr><tr><td>Deepak</td><td>Bangalore</td><td>2500</td><td>2</td></tr><tr><td>Manoj</td><td>Bangalore</td><td>2400</td><td>4</td></tr><tr><td>Meena</td><td>Bangalore</td><td>2300</td><td>5</td></tr><tr><td>Neha</td><td>Bangalore</td><td>2200</td><td>6</td></tr><tr><td>Sneha</td><td>Chennai</td><td>3000</td><td>1</td></tr><tr><td>Vikas</td><td>Chennai</td><td>3000</td><td>1</td></tr><tr><td>Suresh</td><td>Chennai</td><td>2800</td><td>3</td></tr><tr><td>Raj</td><td>Chennai</td><td>2700</td><td>4</td></tr><tr><td>Nisha</td><td>Chennai</td><td>2600</td><td>5</td></tr><tr><td>Divya</td><td>Chennai</td><td>2100</td><td>6</td></tr><tr><td>Amit</td><td>Chennai</td><td>2000</td><td>7</td></tr><tr><td>Priya</td><td>Chennai</td><td>2000</td><td>7</td></tr><tr><td>Simran</td><td>Hyderabad</td><td>2000</td><td>1</td></tr><tr><td>Karthik</td><td>Hyderabad</td><td>1900</td><td>2</td></tr><tr><td>Arjun</td><td>Hyderabad</td><td>1800</td><td>3</td></tr><tr><td>Anjali</td><td>Hyderabad</td><td>1700</td><td>4</td></tr><tr><td>Pooja</td><td>Hyderabad</td><td>1600</td><td>5</td></tr><tr><td>Ravi</td><td>Hyderabad</td><td>1500</td><td>6</td></tr></tbody></table></div>

-- %%
-- 14. Rank employees within each department based on salary (lowest first)
SELECT 
    emp_name,
    department,
    salary,
    RANK() OVER (
        PARTITION BY department
        ORDER BY salary ASC
    ) AS rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>department</th><th>salary</th><th>rank_num</th></tr></thead><tbody><tr><td>Neha</td><td>Bangalore</td><td>2200</td><td>1</td></tr><tr><td>Meena</td><td>Bangalore</td><td>2300</td><td>2</td></tr><tr><td>Manoj</td><td>Bangalore</td><td>2400</td><td>3</td></tr><tr><td>Kiran</td><td>Bangalore</td><td>2500</td><td>4</td></tr><tr><td>Deepak</td><td>Bangalore</td><td>2500</td><td>4</td></tr><tr><td>Rahul</td><td>Bangalore</td><td>2600</td><td>6</td></tr><tr><td>Amit</td><td>Chennai</td><td>2000</td><td>1</td></tr><tr><td>Priya</td><td>Chennai</td><td>2000</td><td>1</td></tr><tr><td>Divya</td><td>Chennai</td><td>2100</td><td>3</td></tr><tr><td>Nisha</td><td>Chennai</td><td>2600</td><td>4</td></tr><tr><td>Raj</td><td>Chennai</td><td>2700</td><td>5</td></tr><tr><td>Suresh</td><td>Chennai</td><td>2800</td><td>6</td></tr><tr><td>Sneha</td><td>Chennai</td><td>3000</td><td>7</td></tr><tr><td>Vikas</td><td>Chennai</td><td>3000</td><td>7</td></tr><tr><td>Ravi</td><td>Hyderabad</td><td>1500</td><td>1</td></tr><tr><td>Pooja</td><td>Hyderabad</td><td>1600</td><td>2</td></tr><tr><td>Anjali</td><td>Hyderabad</td><td>1700</td><td>3</td></tr><tr><td>Arjun</td><td>Hyderabad</td><td>1800</td><td>4</td></tr><tr><td>Karthik</td><td>Hyderabad</td><td>1900</td><td>5</td></tr><tr><td>Simran</td><td>Hyderabad</td><td>2000</td><td>6</td></tr></tbody></table></div>

-- %%
-- 15. Rank employees based on name alphabetically
SELECT 
    emp_name,
    RANK() OVER (
        ORDER BY emp_name ASC
    ) AS rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>rank_num</th></tr></thead><tbody><tr><td>Amit</td><td>1</td></tr><tr><td>Anjali</td><td>2</td></tr><tr><td>Arjun</td><td>3</td></tr><tr><td>Deepak</td><td>4</td></tr><tr><td>Divya</td><td>5</td></tr><tr><td>Karthik</td><td>6</td></tr><tr><td>Kiran</td><td>7</td></tr><tr><td>Manoj</td><td>8</td></tr><tr><td>Meena</td><td>9</td></tr><tr><td>Neha</td><td>10</td></tr><tr><td>Nisha</td><td>11</td></tr><tr><td>Pooja</td><td>12</td></tr><tr><td>Priya</td><td>13</td></tr><tr><td>Rahul</td><td>14</td></tr><tr><td>Raj</td><td>15</td></tr><tr><td>Ravi</td><td>16</td></tr><tr><td>Simran</td><td>17</td></tr><tr><td>Sneha</td><td>18</td></tr><tr><td>Suresh</td><td>19</td></tr><tr><td>Vikas</td><td>20</td></tr></tbody></table></div>

-- %%
-- 16. Rank orders within each city based on order date (latest first)
SELECT 
    emp_name,
    department AS city,
    join_date AS order_date,
    RANK() OVER (
        PARTITION BY department
        ORDER BY join_date DESC
    ) AS rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>city</th><th>order_date</th><th>rank_num</th></tr></thead><tbody><tr><td>Deepak</td><td>Bangalore</td><td>2023-01-19</td><td>1</td></tr><tr><td>Meena</td><td>Bangalore</td><td>2023-01-16</td><td>2</td></tr><tr><td>Manoj</td><td>Bangalore</td><td>2023-01-13</td><td>3</td></tr><tr><td>Rahul</td><td>Bangalore</td><td>2023-01-10</td><td>4</td></tr><tr><td>Neha</td><td>Bangalore</td><td>2023-01-07</td><td>5</td></tr><tr><td>Kiran</td><td>Bangalore</td><td>2023-01-04</td><td>6</td></tr><tr><td>Nisha</td><td>Chennai</td><td>2023-01-20</td><td>1</td></tr><tr><td>Raj</td><td>Chennai</td><td>2023-01-17</td><td>2</td></tr><tr><td>Divya</td><td>Chennai</td><td>2023-01-14</td><td>3</td></tr><tr><td>Suresh</td><td>Chennai</td><td>2023-01-11</td><td>4</td></tr><tr><td>Vikas</td><td>Chennai</td><td>2023-01-08</td><td>5</td></tr><tr><td>Priya</td><td>Chennai</td><td>2023-01-05</td><td>6</td></tr><tr><td>Sneha</td><td>Chennai</td><td>2023-01-03</td><td>7</td></tr><tr><td>Amit</td><td>Chennai</td><td>2023-01-01</td><td>8</td></tr><tr><td>Simran</td><td>Hyderabad</td><td>2023-01-18</td><td>1</td></tr><tr><td>Karthik</td><td>Hyderabad</td><td>2023-01-15</td><td>2</td></tr><tr><td>Pooja</td><td>Hyderabad</td><td>2023-01-12</td><td>3</td></tr><tr><td>Anjali</td><td>Hyderabad</td><td>2023-01-09</td><td>4</td></tr><tr><td>Arjun</td><td>Hyderabad</td><td>2023-01-06</td><td>5</td></tr><tr><td>Ravi</td><td>Hyderabad</td><td>2023-01-02</td><td>6</td></tr></tbody></table></div>

-- %% [markdown]
-- ###DENSE_RANK()

-- %%
-- 17. Assign dense rank to employees based on salary (highest first)
SELECT 
    emp_name,
    salary,
    DENSE_RANK() OVER (
        ORDER BY salary DESC
    ) AS dense_rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary</th><th>dense_rank_num</th></tr></thead><tbody><tr><td>Vikas</td><td>3000</td><td>1</td></tr><tr><td>Sneha</td><td>3000</td><td>1</td></tr><tr><td>Suresh</td><td>2800</td><td>2</td></tr><tr><td>Raj</td><td>2700</td><td>3</td></tr><tr><td>Nisha</td><td>2600</td><td>4</td></tr><tr><td>Rahul</td><td>2600</td><td>4</td></tr><tr><td>Kiran</td><td>2500</td><td>5</td></tr><tr><td>Deepak</td><td>2500</td><td>5</td></tr><tr><td>Manoj</td><td>2400</td><td>6</td></tr><tr><td>Meena</td><td>2300</td><td>7</td></tr><tr><td>Neha</td><td>2200</td><td>8</td></tr><tr><td>Divya</td><td>2100</td><td>9</td></tr><tr><td>Amit</td><td>2000</td><td>10</td></tr><tr><td>Priya</td><td>2000</td><td>10</td></tr><tr><td>Simran</td><td>2000</td><td>10</td></tr><tr><td>Karthik</td><td>1900</td><td>11</td></tr><tr><td>Arjun</td><td>1800</td><td>12</td></tr><tr><td>Anjali</td><td>1700</td><td>13</td></tr><tr><td>Pooja</td><td>1600</td><td>14</td></tr><tr><td>Ravi</td><td>1500</td><td>15</td></tr></tbody></table></div>

-- %%
-- 18. Assign dense rank within each department based on salary (highest first)
SELECT 
    emp_name,
    department,
    salary,
    DENSE_RANK() OVER (
        PARTITION BY department
        ORDER BY salary DESC
    ) AS dense_rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>department</th><th>salary</th><th>dense_rank_num</th></tr></thead><tbody><tr><td>Rahul</td><td>Bangalore</td><td>2600</td><td>1</td></tr><tr><td>Kiran</td><td>Bangalore</td><td>2500</td><td>2</td></tr><tr><td>Deepak</td><td>Bangalore</td><td>2500</td><td>2</td></tr><tr><td>Manoj</td><td>Bangalore</td><td>2400</td><td>3</td></tr><tr><td>Meena</td><td>Bangalore</td><td>2300</td><td>4</td></tr><tr><td>Neha</td><td>Bangalore</td><td>2200</td><td>5</td></tr><tr><td>Sneha</td><td>Chennai</td><td>3000</td><td>1</td></tr><tr><td>Vikas</td><td>Chennai</td><td>3000</td><td>1</td></tr><tr><td>Suresh</td><td>Chennai</td><td>2800</td><td>2</td></tr><tr><td>Raj</td><td>Chennai</td><td>2700</td><td>3</td></tr><tr><td>Nisha</td><td>Chennai</td><td>2600</td><td>4</td></tr><tr><td>Divya</td><td>Chennai</td><td>2100</td><td>5</td></tr><tr><td>Amit</td><td>Chennai</td><td>2000</td><td>6</td></tr><tr><td>Priya</td><td>Chennai</td><td>2000</td><td>6</td></tr><tr><td>Simran</td><td>Hyderabad</td><td>2000</td><td>1</td></tr><tr><td>Karthik</td><td>Hyderabad</td><td>1900</td><td>2</td></tr><tr><td>Arjun</td><td>Hyderabad</td><td>1800</td><td>3</td></tr><tr><td>Anjali</td><td>Hyderabad</td><td>1700</td><td>4</td></tr><tr><td>Pooja</td><td>Hyderabad</td><td>1600</td><td>5</td></tr><tr><td>Ravi</td><td>Hyderabad</td><td>1500</td><td>6</td></tr></tbody></table></div>

-- %%
-- 19. Assign dense rank to employees based on joining date (latest first)
SELECT 
    emp_name,
    join_date,
    DENSE_RANK() OVER (
        ORDER BY join_date DESC
    ) AS dense_rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>join_date</th><th>dense_rank_num</th></tr></thead><tbody><tr><td>Nisha</td><td>2023-01-20</td><td>1</td></tr><tr><td>Deepak</td><td>2023-01-19</td><td>2</td></tr><tr><td>Simran</td><td>2023-01-18</td><td>3</td></tr><tr><td>Raj</td><td>2023-01-17</td><td>4</td></tr><tr><td>Meena</td><td>2023-01-16</td><td>5</td></tr><tr><td>Karthik</td><td>2023-01-15</td><td>6</td></tr><tr><td>Divya</td><td>2023-01-14</td><td>7</td></tr><tr><td>Manoj</td><td>2023-01-13</td><td>8</td></tr><tr><td>Pooja</td><td>2023-01-12</td><td>9</td></tr><tr><td>Suresh</td><td>2023-01-11</td><td>10</td></tr><tr><td>Rahul</td><td>2023-01-10</td><td>11</td></tr><tr><td>Anjali</td><td>2023-01-09</td><td>12</td></tr><tr><td>Vikas</td><td>2023-01-08</td><td>13</td></tr><tr><td>Neha</td><td>2023-01-07</td><td>14</td></tr><tr><td>Arjun</td><td>2023-01-06</td><td>15</td></tr><tr><td>Priya</td><td>2023-01-05</td><td>16</td></tr><tr><td>Kiran</td><td>2023-01-04</td><td>17</td></tr><tr><td>Sneha</td><td>2023-01-03</td><td>18</td></tr><tr><td>Ravi</td><td>2023-01-02</td><td>19</td></tr><tr><td>Amit</td><td>2023-01-01</td><td>20</td></tr></tbody></table></div>

-- %%
-- 20. Assign dense rank to orders based on order amount (highest first)
SELECT 
    emp_name,
    salary AS order_amount,
    DENSE_RANK() OVER (
        ORDER BY salary DESC
    ) AS dense_rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>order_amount</th><th>dense_rank_num</th></tr></thead><tbody><tr><td>Vikas</td><td>3000</td><td>1</td></tr><tr><td>Sneha</td><td>3000</td><td>1</td></tr><tr><td>Suresh</td><td>2800</td><td>2</td></tr><tr><td>Raj</td><td>2700</td><td>3</td></tr><tr><td>Nisha</td><td>2600</td><td>4</td></tr><tr><td>Rahul</td><td>2600</td><td>4</td></tr><tr><td>Kiran</td><td>2500</td><td>5</td></tr><tr><td>Deepak</td><td>2500</td><td>5</td></tr><tr><td>Manoj</td><td>2400</td><td>6</td></tr><tr><td>Meena</td><td>2300</td><td>7</td></tr><tr><td>Neha</td><td>2200</td><td>8</td></tr><tr><td>Divya</td><td>2100</td><td>9</td></tr><tr><td>Amit</td><td>2000</td><td>10</td></tr><tr><td>Priya</td><td>2000</td><td>10</td></tr><tr><td>Simran</td><td>2000</td><td>10</td></tr><tr><td>Karthik</td><td>1900</td><td>11</td></tr><tr><td>Arjun</td><td>1800</td><td>12</td></tr><tr><td>Anjali</td><td>1700</td><td>13</td></tr><tr><td>Pooja</td><td>1600</td><td>14</td></tr><tr><td>Ravi</td><td>1500</td><td>15</td></tr></tbody></table></div>

-- %%
-- 21. Assign dense rank within each city based on order amount (highest first)
SELECT 
    emp_name,
    department AS city,
    salary AS order_amount,
    DENSE_RANK() OVER (
        PARTITION BY department
        ORDER BY salary DESC
    ) AS dense_rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>city</th><th>order_amount</th><th>dense_rank_num</th></tr></thead><tbody><tr><td>Rahul</td><td>Bangalore</td><td>2600</td><td>1</td></tr><tr><td>Kiran</td><td>Bangalore</td><td>2500</td><td>2</td></tr><tr><td>Deepak</td><td>Bangalore</td><td>2500</td><td>2</td></tr><tr><td>Manoj</td><td>Bangalore</td><td>2400</td><td>3</td></tr><tr><td>Meena</td><td>Bangalore</td><td>2300</td><td>4</td></tr><tr><td>Neha</td><td>Bangalore</td><td>2200</td><td>5</td></tr><tr><td>Sneha</td><td>Chennai</td><td>3000</td><td>1</td></tr><tr><td>Vikas</td><td>Chennai</td><td>3000</td><td>1</td></tr><tr><td>Suresh</td><td>Chennai</td><td>2800</td><td>2</td></tr><tr><td>Raj</td><td>Chennai</td><td>2700</td><td>3</td></tr><tr><td>Nisha</td><td>Chennai</td><td>2600</td><td>4</td></tr><tr><td>Divya</td><td>Chennai</td><td>2100</td><td>5</td></tr><tr><td>Amit</td><td>Chennai</td><td>2000</td><td>6</td></tr><tr><td>Priya</td><td>Chennai</td><td>2000</td><td>6</td></tr><tr><td>Simran</td><td>Hyderabad</td><td>2000</td><td>1</td></tr><tr><td>Karthik</td><td>Hyderabad</td><td>1900</td><td>2</td></tr><tr><td>Arjun</td><td>Hyderabad</td><td>1800</td><td>3</td></tr><tr><td>Anjali</td><td>Hyderabad</td><td>1700</td><td>4</td></tr><tr><td>Pooja</td><td>Hyderabad</td><td>1600</td><td>5</td></tr><tr><td>Ravi</td><td>Hyderabad</td><td>1500</td><td>6</td></tr></tbody></table></div>

-- %%
-- 22. Assign dense rank to employees based on salary (lowest first)
SELECT 
    emp_name,
    salary,
    DENSE_RANK() OVER (
        ORDER BY salary ASC
    ) AS dense_rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary</th><th>dense_rank_num</th></tr></thead><tbody><tr><td>Ravi</td><td>1500</td><td>1</td></tr><tr><td>Pooja</td><td>1600</td><td>2</td></tr><tr><td>Anjali</td><td>1700</td><td>3</td></tr><tr><td>Arjun</td><td>1800</td><td>4</td></tr><tr><td>Karthik</td><td>1900</td><td>5</td></tr><tr><td>Priya</td><td>2000</td><td>6</td></tr><tr><td>Simran</td><td>2000</td><td>6</td></tr><tr><td>Amit</td><td>2000</td><td>6</td></tr><tr><td>Divya</td><td>2100</td><td>7</td></tr><tr><td>Neha</td><td>2200</td><td>8</td></tr><tr><td>Meena</td><td>2300</td><td>9</td></tr><tr><td>Manoj</td><td>2400</td><td>10</td></tr><tr><td>Deepak</td><td>2500</td><td>11</td></tr><tr><td>Kiran</td><td>2500</td><td>11</td></tr><tr><td>Rahul</td><td>2600</td><td>12</td></tr><tr><td>Nisha</td><td>2600</td><td>12</td></tr><tr><td>Raj</td><td>2700</td><td>13</td></tr><tr><td>Suresh</td><td>2800</td><td>14</td></tr><tr><td>Sneha</td><td>3000</td><td>15</td></tr><tr><td>Vikas</td><td>3000</td><td>15</td></tr></tbody></table></div>

-- %%
-- 23. Assign dense rank within each department based on joining date (latest first)
SELECT 
    emp_name,
    department,
    join_date,
    DENSE_RANK() OVER (
        PARTITION BY department
        ORDER BY join_date DESC
    ) AS dense_rank_num
FROM employees;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>department</th><th>join_date</th><th>dense_rank_num</th></tr></thead><tbody><tr><td>Deepak</td><td>Bangalore</td><td>2023-01-19</td><td>1</td></tr><tr><td>Meena</td><td>Bangalore</td><td>2023-01-16</td><td>2</td></tr><tr><td>Manoj</td><td>Bangalore</td><td>2023-01-13</td><td>3</td></tr><tr><td>Rahul</td><td>Bangalore</td><td>2023-01-10</td><td>4</td></tr><tr><td>Neha</td><td>Bangalore</td><td>2023-01-07</td><td>5</td></tr><tr><td>Kiran</td><td>Bangalore</td><td>2023-01-04</td><td>6</td></tr><tr><td>Nisha</td><td>Chennai</td><td>2023-01-20</td><td>1</td></tr><tr><td>Raj</td><td>Chennai</td><td>2023-01-17</td><td>2</td></tr><tr><td>Divya</td><td>Chennai</td><td>2023-01-14</td><td>3</td></tr><tr><td>Suresh</td><td>Chennai</td><td>2023-01-11</td><td>4</td></tr><tr><td>Vikas</td><td>Chennai</td><td>2023-01-08</td><td>5</td></tr><tr><td>Priya</td><td>Chennai</td><td>2023-01-05</td><td>6</td></tr><tr><td>Sneha</td><td>Chennai</td><td>2023-01-03</td><td>7</td></tr><tr><td>Amit</td><td>Chennai</td><td>2023-01-01</td><td>8</td></tr><tr><td>Simran</td><td>Hyderabad</td><td>2023-01-18</td><td>1</td></tr><tr><td>Karthik</td><td>Hyderabad</td><td>2023-01-15</td><td>2</td></tr><tr><td>Pooja</td><td>Hyderabad</td><td>2023-01-12</td><td>3</td></tr><tr><td>Anjali</td><td>Hyderabad</td><td>2023-01-09</td><td>4</td></tr><tr><td>Arjun</td><td>Hyderabad</td><td>2023-01-06</td><td>5</td></tr><tr><td>Ravi</td><td>Hyderabad</td><td>2023-01-02</td><td>6</td></tr></tbody></table></div>
