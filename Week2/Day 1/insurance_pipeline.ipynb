# %%
# %python
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window

# %%
# %python
spark = SparkSession.builder.getOrCreate()

# %%
customers = spark.createDataFrame([(1, 'Cust1', 25, 'Bangalore'), (2, 'Cust2', 52, 'Chennai'), (3, 'Cust3', 46, 'Bangalore'), (4, 'Cust4', 58, 'Hyderabad'), (5, 'Cust5', 36, 'Hyderabad'), (6, 'Cust6', 50, 'Mumbai'), (7, 'Cust7', 43, 'Chennai'), (8, 'Cust8', 32, 'Chennai'), (9, 'Cust9', 47, 'Hyderabad'), (10, 'Cust10', 39, 'Mumbai'), (11, 'Cust11', 42, 'Hyderabad'), (12, 'Cust12', 33, 'Bangalore'), (13, 'Cust13', 57, 'Hyderabad'), (14, 'Cust14', 60, 'Mumbai'), (15, 'Cust15', 30, 'Hyderabad'), (16, 'Cust16', 56, 'Bangalore'), (17, 'Cust17', 51, 'Chennai'), (18, 'Cust18', 36, 'Mumbai'), (19, 'Cust19', 35, 'Hyderabad'), (20, 'Cust20', 43, 'Bangalore'), (21, 'Cust21', 45, 'Chennai'), (22, 'Cust22', 40, 'Hyderabad'), (23, 'Cust23', 30, 'Mumbai'), (24, 'Cust24', 24, 'Mumbai'), (25, 'Cust25', 49, 'Bangalore'), (26, 'Cust26', 31, 'Mumbai'), (27, 'Cust27', 25, 'Chennai'), (28, 'Cust28', 46, 'Bangalore'), (29, 'Cust29', 34, 'Chennai'), (30, 'Cust30', 35, 'Mumbai'), (31, 'Cust31', 20, 'Chennai'), (32, 'Cust32', 35, 'Bangalore'), (33, 'Cust33', 41, 'Mumbai'), (34, 'Cust34', 22, 'Bangalore'), (35, 'Cust35', 59, 'Hyderabad'), (36, 'Cust36', 32, 'Chennai'), (37, 'Cust37', 59, 'Hyderabad'), (38, 'Cust38', 35, 'Chennai'), (39, 'Cust39', 29, 'Mumbai'), (40, 'Cust40', 26, 'Bangalore'), (41, 'Cust41', 51, 'Chennai'), (42, 'Cust42', 25, 'Mumbai'), (43, 'Cust43', 52, 'Mumbai'), (44, 'Cust44', 44, 'Hyderabad'), (45, 'Cust45', 55, 'Mumbai'), (46, 'Cust46', 31, 'Hyderabad'), (47, 'Cust47', 24, 'Bangalore'), (48, 'Cust48', 60, 'Mumbai'), (49, 'Cust49', 26, 'Bangalore'), (50, 'Cust50', 58, 'Bangalore'), (51, 'Cust51', 60, 'Chennai'), (52, 'Cust52', 47, 'Chennai'), (53, 'Cust53', 48, 'Mumbai'), (54, 'Cust54', 25, 'Chennai'), (55, 'Cust55', 27, 'Mumbai'), (56, 'Cust56', 34, 'Chennai'), (57, 'Cust57', 54, 'Bangalore'), (58, 'Cust58', 29, 'Bangalore'), (59, 'Cust59', 51, 'Chennai'), (60, 'Cust60', 39, 'Hyderabad')], ["customer_id","name","age","city"])
2023-03-27', 'Pending'), (253, 157, 9716, '2023-04-05', 'Approved'), (254, 146, 13444, '2023-01-23', 'Approved'), (255, 112, 1432, '2023-10-08', 'Rejected'), (256, 106, 8508, '2023-04-03', 'Rejected'), (257, 103, 8969, '2023-10-11', 'Pending'), (258, 130, 2227, '2023-05-23', 'Pending'), (259, 125, 10332, '2023-10-08', 'Approved'), (260, 171, -1537, '2023-02-19', 'Approved'), (261, 180, 13362, '2023-02-13', 'Rejected'), (262, 157, 2359, '2023-04-24', 'Rejected'), (263, 154, 9574, '2023-08-07', 'Rejected'), (264, 163, 2059, '2023-04-03', 'Rejected'), (265, 101, 7373, '2023-03-14', 'Pending'), (266, 157, 9805, '2023-03-15', 'Approved'), (267, 180, 2053, '2023-07-07', 'Approved'), (268, 111, -964, '2023-07-30', 'Pending'), (269, 170, 2023, '2023-04-20', 'Pending'), (270, 109, 6252, '2023-10-25', 'Pending'), (271, 141, 10757, '2023-01-30', 'Approved'), (272, 164, 12245, '2023-07-14', 'Pending'), (273, 115, 12669, '2023-01-26', 'Rejected'), (274, 128, -731, '2023-08-18', 'Pending'), (275, 199, 9528, '2023-03-16', 'Pending'), (276, 140, 11854, '2023-07-24', 'Approved'), (277, 153, 10356, '2023-08-11', 'Pending'), (278, 192, 9657, '2023-08-24', 'Approved'), (279, 168, 13136, '2023-06-08', 'Approved'), (280, 161, 2476, '2023-06-27', 'Rejected')], ["claim_id","policy_id","claim_amount","claim_date","status"])
agents = spark.createDataFrame([(1, 'Agent1', 'South'), (2, 'Agent2', 'North'), (3, 'Agent3', 'West'), (4, 'Agent4', 'West'), (5, 'Agent5', 'South'), (6, 'Agent6', 'East'), (7, 'Agent7', 'South'), (8, 'Agent8', 'North'), (9, 'Agent9', 'East'), (10, 'Agent10', 'North'), (11, 'Agent11', 'West'), (12, 'Agent12', 'West'), (13, 'Agent13', 'South'), (14, 'Agent14', 'East'), (15, 'Agent15', 'North'), (16, 'Agent16', 'North'), (17, 'Agent17', 'South'), (18, 'Agent18', 'East'), (19, 'Agent19', 'East'), (20, 'Agent20', 'North')], ["agent_id","name","region"])
policy_agent = spark.createDataFrame([(125, 15), (105, 5), (115, 9), (130, 12), (143, 5), (120, 18), (143, 11), (116, 11), (166, 7), (108, 20), (131, 9), (180, 2), (106, 15), (102, 15), (161, 5), (110, 12), (145, 13), (158, 17), (132, 1), (148, 1), (134, 13), (136, 5), (174, 2), (171, 3), (114, 9), (129, 14), (109, 6), (141, 12), (166, 13), (142, 7), (133, 14), (163, 3), (156, 10), (145, 8), (119, 1), (121, 19), (123, 14), (111, 4), (122, 12), (134, 15), (101, 1), (135, 16), (133, 7), (123, 10), (144, 11), (124, 19), (178, 6), (165, 20), (158, 5), (115, 13), (102, 10), (106, 6), (150, 8), (126, 20), (140, 6), (136, 20), (153, 3), (178, 19), (124, 5), (160, 14), (151, 20), (162, 14), (131, 11), (109, 1), (124, 9), (109, 3), (106, 4), (143, 6), (175, 15), (165, 15), (116, 3), (130, 4), (174, 19), (164, 6), (148, 10), (177, 1), (105, 2), (114, 5), (130, 14), (156, 20)], ["policy_id","agent_id"])

# %%
policies = policies.withColumn("start_date", to_date(col("start_date")))
claims = claims.withColumn("claim_date", to_date(col("claim_date")))

# %%
display(customers)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>name</th><th
tr><tr><td>156</td><td>10</td></tr><tr><td>145</td><td>8</td></tr><tr><td>119</td><td>1</td></tr><tr><td>121</td><td>19</td></tr><tr><td>123</td><td>14</td></tr><tr><td>111</td><td>4</td></tr><tr><td>122</td><td>12</td></tr><tr><td>134</td><td>15</td></tr><tr><td>101</td><td>1</td></tr><tr><td>135</td><td>16</td></tr><tr><td>133</td><td>7</td></tr><tr><td>123</td><td>10</td></tr><tr><td>144</td><td>11</td></tr><tr><td>124</td><td>19</td></tr><tr><td>178</td><td>6</td></tr><tr><td>165</td><td>20</td></tr><tr><td>158</td><td>5</td></tr><tr><td>115</td><td>13</td></tr><tr><td>102</td><td>10</td></tr><tr><td>106</td><td>6</td></tr><tr><td>150</td><td>8</td></tr><tr><td>126</td><td>20</td></tr><tr><td>140</td><td>6</td></tr><tr><td>136</td><td>20</td></tr><tr><td>153</td><td>3</td></tr><tr><td>178</td><td>19</td></tr><tr><td>124</td><td>5</td></tr><tr><td>160</td><td>14</td></tr><tr><td>151</td><td>20</td></tr><tr><td>162</td><td>14</td></tr><tr><td>131</td><td>11</td></tr><tr><td>109</td><td>1</td></tr><tr><td>124</td><td>9</td></tr><tr><td>109</td><td>3</td></tr><tr><td>106</td><td>4</td></tr><tr><td>143</td><td>6</td></tr><tr><td>175</td><td>15</td></tr><tr><td>165</td><td>15</td></tr><tr><td>116</td><td>3</td></tr><tr><td>130</td><td>4</td></tr><tr><td>174</td><td>19</td></tr><tr><td>164</td><td>6</td></tr><tr><td>148</td><td>10</td></tr><tr><td>177</td><td>1</td></tr><tr><td>105</td><td>2</td></tr><tr><td>114</td><td>5</td></tr><tr><td>130</td><td>14</td></tr><tr><td>156</td><td>20</td></tr></tbody></table></div>

# %% [markdown]
# ### Data Understanding

# %%
#check schema
customers.printSchema()
policies.printSchema()
claims.printSchema()
agents.printSchema()
policy_agent.printSchema()
# Out:
# root
#  |-- customer_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- city: string (nullable = true)
#
# root
#  |-- policy_id: long (nullable = true)
#  |-- customer_id: long (nullable = true)
#  |-- policy_type: string (nullable = true)
#  |-- premium: long (nullable = true)
#  |-- start_date: date (nullable = true)
#
# root
#  |-- claim_id: long (nullable = true)
#  |-- policy_id: long (nullable = true)
#  |-- claim_amount: long (nullable = true)
#  |-- claim_date: date (nullable = true)
#  |-- status: string (nullable = true)
#
# root
#  |-- agent_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- region: string (nullable = true)
#
# root
#  |-- policy_id: long (nullable = true)
#  |-- agent_id: long (nullable = true)

# %%
# check row count
print("customers : ", customers.count())
print("policies : ", policies.count())
print("claims : ", claims.count())
print("agents : ", agents.count())
print("policy_agent : ",policy_agent.count())
# Out:
# customers :  60
# policies :  80
# claims :  80
# agents :  20
# policy_agent :  80

# %%
# identify nullvalues
customers.select([count(when(col(c).isNull(),c)).alias(c) for c in customers.columns]).show()
policies.select([count(when(col(c).isNull(),c)).alias(c) for c in policies.columns]).show()
claims.select([count(when(col(c).isNull(),c)).alias(c) for c in claims.columns]).show()
agents.select([count(when(col(c).isNull(),c)).alias(c) for c in agents.columns]).show()
policy_agent.select([count(when(col(c).isNull(),c)).alias(c) for c in policy_agent.columns]).show()
# Out:
# +-----------+----+---+----+
# |customer_id|name|age|city|
# +-----------+----+---+----+
# |          0|   0|  0|   0|
# +-----------+----+---+----+
#
# +---------+-----------+-----------+-------+----------+
# |policy_id|customer_id|policy_type|premium|start_date|
# +---------+-----------+-----------+-------+----------+
# |        0|          0|          0|      0|         0|
# +---------+-----------+-----------+-------+----------+
#
# +--------+---------+------------+----------+------+
# |claim_id|policy_id|claim_amount|claim_date|status|
# +--------+---------+------------+----------+------+
# |       0|        0|           0|         0|     0|
# +--------+---------+------------+----------+------+
#
# +--------+----+------+
# |agent_id|name|region|
# +--------+----+------+
# |       0|   0|     0|
# +--------+----+------+
#
# +---------+--------+
# |policy_id|agent_id|
# +---------+--------+
# |        0|       0|
# +---------+--------+

# %%
# identify negative values
policies.filter(col('premium')>0).show()
claims.filter(col('claim_amount')>0).show()
# Out:
# +---------+-----------+-----------+-------+----------+
# |policy_id|customer_id|policy_type|premium|start_date|
# +---------+-----------+-----------+-------+----------+
# |      101|         46|       Life|    378|2023-08-12|
# |      102|         60|       Auto|  13450|2023-09-10|
# |      104|         53|       Auto|  16546|2023-08-19|
# |      108|         58|       Auto|   2618|2023-10-05|
# |      109|         17|       Life|   1509|2023-02-26|
# |      110|          9|       Life|  10514|2023-05-10|
# |      111|         11|     Health|   6363|2023-02-20|
# |      112|         14|       Life|  16596|2023-10-23|
# |      113|         12|       Auto|   9760|2023-10-28|
# |      116|         15|       Auto|  11693|2023-08-18|
# |      117|         28|       Life|  19215|2023-02-09|
# |      118|         70|       Auto|   1960|2023-08-21|
# |      119|         18|     Health|  15604|2023-08-07|
# |      120|         69|       Life|   2812|2023-01-09|
# |      121|         34|       Life|  10463|2023-03-29|
# |      122|         65|       Auto|   3456|2023-05-07|
# |      123|         44|     Health|  12480|2023-09-26|
# |      125|         63|     Health|  14463|2023-02-17|
# |      127|          4|     Health|   1795|2023-07-08|
# |      128|         50|       Auto|  17211|2023-03-12|
# +---------+-----------+-----------+-------+----------+
# only showing top 20 rows
# +--------+---------+------------+----------+--------+
# |claim_id|policy_id|claim_amount|claim_date|  status|
# +--------+---------+------------+----------+--------+
# |     201|      128|        2016|2023-07-04|Rejected|
# |     202|      189|        3524|2023-06-10|Approved|
# |     203|      151|        6667|2023-02-05|Rejected|
# |     204|      170|        5569|2023-02-15|Rejected|
# |     205|      153|       13249|2023-09-01|Rejected|
# |     206|      150|        8459|2023-03-28|Rejected|
# |     207|      152|       11831|2023-06-07| Pending|
# |     208|      150|        5932|2023-05-22|Approved|
# |     209|      170|        8158|2023-04-30| Pending|
# |     210|      156|       13267|2023-07-13|Approved|
# |     211|      182|       12279|2023-08-08|Rejected|
# |     212|      174|       13997|2023-03-21| Pending|
# |     213|      119|        7369|2023-08-23|Rejected|
# |     214|      168|       14982|2023-06-08| Pending|
# |     215|      146|       13203|2023-03-02|Rejected|
# |     216|      161|        4108|2023-07-07|Approved|
# |     218|      125|        9804|2023-09-13|Approved|
# |     219|      112|        6109|2023-02-17| Pending|
# |     220|      162|       13753|2023-07-16| Pending|
# |     221|      190|       11134|2023-04-12|Approved|
# +--------+---------+------------+----------+--------+
# only showing top 20 rows

# %%
# identify invalid keys
policies.join(customers, "customer_id", "left_anti").show()
# Out:
# +-----------+---------+-----------+-------+----------+
# |customer_id|policy_id|policy_type|premium|start_date|
# +-----------+---------+-----------+-------+----------+
# |         70|      118|       Auto|   1960|2023-08-21|
# |         69|      120|       Life|   2812|2023-01-09|
# |         65|      122|       Auto|   3456|2023-05-07|
# |         63|      125|     Health|  14463|2023-02-17|
# |         65|      133|       Life|  -2649|2023-09-07|
# |         61|      140|       Auto|   -830|2023-04-14|
# |         69|      144|       Auto|  -4821|2023-10-13|
# |         67|      148|     Health|   8126|2023-02-20|
# |         65|      159|     Health|  14550|2023-06-02|
# |         61|      162|     Health|    461|2023-08-30|
# +-----------+---------+-----------+-------+----------+

# %%
claims.join(policies, "policy_id","left_anti").show()
# Out:
# +---------+--------+------------+----------+--------+
# |policy_id|claim_id|claim_amount|claim_date|  status|
# +---------+--------+------------+----------+--------+
# |      189|     202|        3524|2023-06-10|Approved|
# |      182|     211|       12279|2023-08-08|Rejected|
# |      194|     217|        -344|2023-05-22| Pending|
# |      190|     221|       11134|2023-04-12|Approved|
# |      198|     225|       -1849|2023-03-24|Approved|
# |      181|     226|        6380|2023-08-07|Approved|
# |      185|     240|        1512|2023-10-11| Pending|
# |      188|     242|        2507|2023-08-06| Pending|
# |      189|     243|        -425|2023-09-22|Rejected|
# |      184|     248|       11409|2023-09-10|Rejected|
# |      190|     252|        7154|2023-03-27| Pending|
# |      199|     275|        9528|2023-03-16| Pending|
# |      192|     278|        9657|2023-08-24|Approved|
# +---------+--------+------------+----------+--------+

# %%
# %sql
WITH premium_cte AS (
    SELECT 
        customer_id,
        SUM(premium) AS total_premium
    FROM policies
    GROUP BY customer_id
),

claims_cte AS (
    SELECT 
        p.customer_id,
        SUM(c.claim_amount) AS total_claims
    FROM claims c
    JOIN policies p ON c.policy_id = p.policy_id
    GROUP BY p.customer_id
),

risk_cte AS (
    SELECT 
        c.customer_id,
        c.city,
        COALESCE(cl.total_claims, 0) AS total_claims,
        COALESCE(pr.total_premium, 0) AS total_premium,
        CASE 
            WHEN pr.total_premium = 0 THEN 0
            ELSE cl.total_claims / pr.total_premium
        END AS risk_score
    FROM customers c
    LEFT JOIN premium_cte pr ON c.customer_id = pr.customer_id
    LEFT JOIN claims_cte cl ON c.customer_id = cl.customer_id
),

rank_cte AS (
    SELECT *,
           ROW_NUMBER() OVER (PARTITION BY city ORDER BY risk_score DESC) AS rank
    FROM risk_cte
)

SELECT *
FROM rank_cte
WHERE rank <= 3;
# Out:
# +---------+--------+
# |policy_id|agent_id|
# +---------+--------+
# +---------+--------+
#
# +--------+---------+
# |agent_id|policy_id|
# +--------+---------+
# +--------+---------+

# %% [markdown]
# ### Data cleaning

# %%
# Remove rows where customer_id is null (important key)
customers_clean = customers.dropna(subset=["customer_id"])

# Fill null values
customers_clean = customers_clean.fillna({
    "name": "Unknown",
    "age": 0,
    "city": "Unknown"
})

# Trim and standardize strings
customers_clean = customers_clean.withColumn("name", trim(col("name")))
customers_clean = customers_clean.withColumn("city", initcap(trim(col("city"))))

customers_clean.show()
# Out:
# +-----------+------+---+---------+
# |customer_id|  name|age|     city|
# +-----------+------+---+---------+
# |          1| Cust1| 25|Bangalore|
# |          2| Cust2| 52|  Chennai|
# |          3| Cust3| 46|Bangalore|
# |          4| Cust4| 58|Hyderabad|
# |          5| Cust5| 36|Hyderabad|
# |          6| Cust6| 50|   Mumbai|
# |          7| Cust7| 43|  Chennai|
# |          8| Cust8| 32|  Chennai|
# |          9| Cust9| 47|Hyderabad|
# |         10|Cust10| 39|   Mumbai|
# |         11|Cust11| 42|Hyderabad|
# |         12|Cust12| 33|Bangalore|
# |         13|Cust13| 57|Hyderabad|
# |         14|Cust14| 60|   Mumbai|
# |         15|Cust15| 30|Hyderabad|
# |         16|Cust16| 56|Bangalore|
# |         17|Cust17| 51|  Chennai|
# |         18|Cust18| 36|   Mumbai|
# |         19|Cust19| 35|Hyderabad|
# |         20|Cust20| 43|Bangalore|
# +-----------+------+---+---------+
# only showing top 20 rows

# %%
# Remove invalid premium values
policies_clean = policies.filter(col("premium") >= 0)

# Drop null keys
policies_clean = policies_clean.dropna(subset=["policy_id", "customer_id"])

# Fill null policy_type
policies_clean = policies_clean.fillna({
    "policy_type": "Unknown",
    "premium": 0
})

# Standardize strings
policies_clean = policies_clean.withColumn("policy_type", initcap(trim(col("policy_type"))))

# Ensure date format
policies_clean = policies_clean.withColumn("start_date", to_date(col("start_date")))

policies_clean.show()
# Out:
# +---------+-----------+-----------+-------+----------+
# |policy_id|customer_id|policy_type|premium|start_date|
# +---------+-----------+-----------+-------+----------+
# |      101|         46|       Life|    378|2023-08-12|
# |      102|         60|       Auto|  13450|2023-09-10|
# |      104|         53|       Auto|  16546|2023-08-19|
# |      108|         58|       Auto|   2618|2023-10-05|
# |      109|         17|       Life|   1509|2023-02-26|
# |      110|          9|       Life|  10514|2023-05-10|
# |      111|         11|     Health|   6363|2023-02-20|
# |      112|         14|       Life|  16596|2023-10-23|
# |      113|         12|       Auto|   9760|2023-10-28|
# |      116|         15|       Auto|  11693|2023-08-18|
# |      117|         28|       Life|  19215|2023-02-09|
# |      118|         70|       Auto|   1960|2023-08-21|
# |      119|         18|     Health|  15604|2023-08-07|
# |      120|         69|       Life|   2812|2023-01-09|
# |      121|         34|       Life|  10463|2023-03-29|
# |      122|         65|       Auto|   3456|2023-05-07|
# |      123|         44|     Health|  12480|2023-09-26|
# |      125|         63|     Health|  14463|2023-02-17|
# |      127|          4|     Health|   1795|2023-07-08|
# |      128|         50|       Auto|  17211|2023-03-12|
# +---------+-----------+-----------+-------+----------+
# only showing top 20 rows

# %%
# Remove negative claim amounts
claims_clean = claims.filter(col("claim_amount") >= 0)

# Drop null keys
claims_clean = claims_clean.dropna(subset=["claim_id", "policy_id"])

# Fill null status
claims_clean = claims_clean.fillna({
    "status": "Unknown"
})

# Standardize status
claims_clean = claims_clean.withColumn("status", initcap(trim(col("status"))))

# Ensure date format
claims_clean = claims_clean.withColumn("claim_date", to_date(col("claim_date")))

claims_clean.show()
# Out:
# +--------+---------+------------+----------+--------+
# |claim_id|policy_id|claim_amount|claim_date|  status|
# +--------+---------+------------+----------+--------+
# |     201|      128|        2016|2023-07-04|Rejected|
# |     202|      189|        3524|2023-06-10|Approved|
# |     203|      151|        6667|2023-02-05|Rejected|
# |     204|      170|        5569|2023-02-15|Rejected|
# |     205|      153|       13249|2023-09-01|Rejected|
# |     206|      150|        8459|2023-03-28|Rejected|
# |     207|      152|       11831|2023-06-07| Pending|
# |     208|      150|        5932|2023-05-22|Approved|
# |     209|      170|        8158|2023-04-30| Pending|
# |     210|      156|       13267|2023-07-13|Approved|
# |     211|      182|       12279|2023-08-08|Rejected|
# |     212|      174|       13997|2023-03-21| Pending|
# |     213|      119|        7369|2023-08-23|Rejected|
# |     214|      168|       14982|2023-06-08| Pending|
# |     215|      146|       13203|2023-03-02|Rejected|
# |     216|      161|        4108|2023-07-07|Approved|
# |     218|      125|        9804|2023-09-13|Approved|
# |     219|      112|        6109|2023-02-17| Pending|
# |     220|      162|       13753|2023-07-16| Pending|
# |     221|      190|       11134|2023-04-12|Approved|
# +--------+---------+------------+----------+--------+
# only showing top 20 rows

# %%
# remove nulls
agents_clean = agents.dropna(subset=["agent_id"])

# Fill null values
agents_clean = agents_clean.fillna({
    "name": "Unknown",
    "region": "Unknown"
})

# Standardize strings
agents_clean = agents_clean.withColumn("name", trim(col("name")))
agents_clean = agents_clean.withColumn("region", initcap(trim(col("region"))))

agents_clean.show()
# Out:
# +--------+-------+------+
# |agent_id|   name|region|
# +--------+-------+------+
# |       1| Agent1| South|
# |       2| Agent2| North|
# |       3| Agent3|  West|
# |       4| Agent4|  West|
# |       5| Agent5| South|
# |       6| Agent6|  East|
# |       7| Agent7| South|
# |       8| Agent8| North|
# |       9| Agent9|  East|
# |      10|Agent10| North|
# |      11|Agent11|  West|
# |      12|Agent12|  West|
# |      13|Agent13| South|
# |      14|Agent14|  East|
# |      15|Agent15| North|
# |      16|Agent16| North|
# |      17|Agent17| South|
# |      18|Agent18|  East|
# |      19|Agent19|  East|
# |      20|Agent20| North|
# +--------+-------+------+

# %%
# Remove nulls
policy_agent_clean = policy_agent.dropna(subset=["policy_id", "agent_id"])

# Remove duplicates
policy_agent_clean = policy_agent_clean.dropDuplicates()

policy_agent_clean.show()
# Out:
# +---------+--------+
# |policy_id|agent_id|
# +---------+--------+
# |      125|      15|
# |      105|       5|
# |      115|       9|
# |      130|      12|
# |      143|       5|
# |      120|      18|
# |      143|      11|
# |      116|      11|
# |      166|       7|
# |      108|      20|
# |      131|       9|
# |      180|       2|
# |      106|      15|
# |      102|      15|
# |      161|       5|
# |      110|      12|
# |      145|      13|
# |      158|      17|
# |      132|       1|
# |      148|       1|
# +---------+--------+
# only showing top 20 rows

# %% [markdown]
# ### Data Validation

# %%
customers_clean.join(policies_clean, "customer_id", "left_anti").show()

policies_clean.join(claims_clean, "policy_id", "left_anti").show()

policy_agent_clean.join(agents_clean, "agent_id", "left_anti").show()

policy_agent_clean.join(policies_clean, "policy_id", "left_anti").show()
# Out:
# +-----------+------+---+---------+
# |customer_id|  name|age|     city|
# +-----------+------+---+---------+
# |          2| Cust2| 52|  Chennai|
# |          3| Cust3| 46|Bangalore|
# |          5| Cust5| 36|Hyderabad|
# |          6| Cust6| 50|   Mumbai|
# |          7| Cust7| 43|  Chennai|
# |         10|Cust10| 39|   Mumbai|
# |         13|Cust13| 57|Hyderabad|
# |         20|Cust20| 43|Bangalore|
# |         22|Cust22| 40|Hyderabad|
# |         23|Cust23| 30|   Mumbai|
# |         24|Cust24| 24|   Mumbai|
# |         26|Cust26| 31|   Mumbai|
# |         27|Cust27| 25|  Chennai|
# |         29|Cust29| 34|  Chennai|
# |         30|Cust30| 35|   Mumbai|
# |         35|Cust35| 59|Hyderabad|
# |         36|Cust36| 32|  Chennai|
# |         37|Cust37| 59|Hyderabad|
# |         38|Cust38| 35|  Chennai|
# |         39|Cust39| 29|   Mumbai|
# +-----------+------+---+---------+
# only showing top 20 rows
# +---------+-----------+-----------+-------+----------+
# |policy_id|customer_id|policy_type|premium|start_date|
# +---------+-----------+-----------+-------+----------+
# |      102|         60|       Auto|  13450|2023-09-10|
# |      104|         53|       Auto|  16546|2023-08-19|
# |      110|          9|       Life|  10514|2023-05-10|
# |      111|         11|     Health|   6363|2023-02-20|
# |      113|         12|       Auto|   9760|2023-10-28|
# |      116|         15|       Auto|  11693|2023-08-18|
# |      117|         28|       Life|  19215|2023-02-09|
# |      120|         69|       Life|   2812|2023-01-09|
# |      121|         34|       Life|  10463|2023-03-29|
# |      123|         44|     Health|  12480|2023-09-26|
# |      131|         43|     Health|  16770|2023-05-16|
# |      136|         17|     Health|    514|2023-10-17|
# |      137|         31|       Life|  11807|2023-05-11|
# |      142|         45|       Auto|  15333|2023-10-14|
# |      147|         25|     Health|  11188|2023-02-23|
# |      148|         67|     Health|   8126|2023-02-20|
# |      149|         18|     Health|  17409|2023-08-07|
# |      159|         65|     Health|  14550|2023-06-02|
# |      160|         28|       Auto|  11985|2023-08-20|
# |      165|         45|       Life|   3812|2023-10-10|
# +---------+-----------+-----------+-------+----------+
# only showing top 20 rows
# +--------+---------+
# |agent_id|policy_id|
# +--------+---------+
# +--------+---------+
#
# +---------+--------+
# |policy_id|agent_id|
# +---------+--------+
# |      105|       5|
# |      115|       9|
# |      143|      11|
# |      143|       5|
# |      132|       1|
# |      158|      17|
# |      106|      15|
# |      129|      14|
# |      134|      13|
# |      114|       9|
# |      141|      12|
# |      133|      14|
# |      163|       3|
# |      134|      15|
# |      133|       7|
# |      144|      11|
# |      115|      13|
# |      124|      19|
# |      158|       5|
# |      178|       6|
# +---------+--------+
# only showing top 20 rows

# %%
print("Before Cleaning")
print("Customers:", customers.count())
print("Policies:", policies.count())
print("Claims:", claims.count())
print("Agents:", agents.count())
print("Policy-Agent:", policy_agent.count())

print("After Cleaning")
print("Customers:", customers_clean.count())
print("Policies:", policies_clean.count())
print("Claims:", claims_clean.count())
print("Agents:", agents_clean.count())
print("Policy-Agent:", policy_agent_clean.count())
# Out:
# Before Cleaning
# Customers: 60
# Policies: 80
# Claims: 80
# Agents: 20
# Policy-Agent: 80
# After Cleaning
# Customers: 60
# Policies: 56
# Claims: 70
# Agents: 20
# Policy-Agent: 80

# %% [markdown]
# ### Transformations

# %%
#Compute total premium per customer
customers_clean.join(policies_clean, "customer_id").groupBy("name").agg(sum(col("premium"))).show()
# Out:
# +------+------------+
# |  name|sum(premium)|
# +------+------------+
# | Cust4|       16719|
# | Cust1|       17437|
# | Cust9|       10514|
# |Cust11|       21871|
# | Cust8|        9978|
# |Cust15|       11693|
# |Cust14|       16596|
# |Cust12|       25754|
# |Cust17|       13706|
# |Cust18|       39181|
# |Cust19|       17219|
# |Cust21|        6560|
# |Cust16|       11196|
# |Cust25|       11188|
# |Cust28|       31200|
# |Cust31|       26511|
# |Cust32|       11973|
# |Cust34|       16357|
# |Cust33|       15090|
# |Cust43|       16770|
# +------+------------+
# only showing top 20 rows

# %%
claims_clean.show()
policies_clean.show()
# Out:
# +--------+---------+------------+----------+--------+
# |claim_id|policy_id|claim_amount|claim_date|  status|
# +--------+---------+------------+----------+--------+
# |     201|      128|        2016|2023-07-04|Rejected|
# |     202|      189|        3524|2023-06-10|Approved|
# |     203|      151|        6667|2023-02-05|Rejected|
# |     204|      170|        5569|2023-02-15|Rejected|
# |     205|      153|       13249|2023-09-01|Rejected|
# |     206|      150|        8459|2023-03-28|Rejected|
# |     207|      152|       11831|2023-06-07| Pending|
# |     208|      150|        5932|2023-05-22|Approved|
# |     209|      170|        8158|2023-04-30| Pending|
# |     210|      156|       13267|2023-07-13|Approved|
# |     211|      182|       12279|2023-08-08|Rejected|
# |     212|      174|       13997|2023-03-21| Pending|
# |     213|      119|        7369|2023-08-23|Rejected|
# |     214|      168|       14982|2023-06-08| Pending|
# |     215|      146|       13203|2023-03-02|Rejected|
# |     216|      161|        4108|2023-07-07|Approved|
# |     218|      125|        9804|2023-09-13|Approved|
# |     219|      112|        6109|2023-02-17| Pending|
# |     220|      162|       13753|2023-07-16| Pending|
# |     221|      190|       11134|2023-04-12|Approved|
# +--------+---------+------------+----------+--------+
# only showing top 20 rows
# +---------+-----------+-----------+-------+----------+
# |policy_id|customer_id|policy_type|premium|start_date|
# +---------+-----------+-----------+-------+----------+
# |      101|         46|       Life|    378|2023-08-12|
# |      102|         60|       Auto|  13450|2023-09-10|
# |      104|         53|       Auto|  16546|2023-08-19|
# |      108|         58|       Auto|   2618|2023-10-05|
# |      109|         17|       Life|   1509|2023-02-26|
# |      110|          9|       Life|  10514|2023-05-10|
# |      111|         11|     Health|   6363|2023-02-20|
# |      112|         14|       Life|  16596|2023-10-23|
# |      113|         12|       Auto|   9760|2023-10-28|
# |      116|         15|       Auto|  11693|2023-08-18|
# |      117|         28|       Life|  19215|2023-02-09|
# |      118|         70|       Auto|   1960|2023-08-21|
# |      119|         18|     Health|  15604|2023-08-07|
# |      120|         69|       Life|   2812|2023-01-09|
# |      121|         34|       Life|  10463|2023-03-29|
# |      122|         65|       Auto|   3456|2023-05-07|
# |      123|         44|     Health|  12480|2023-09-26|
# |      125|         63|     Health|  14463|2023-02-17|
# |      127|          4|     Health|   1795|2023-07-08|
# |      128|         50|       Auto|  17211|2023-03-12|
# +---------+-----------+-----------+-------+----------+
# only showing top 20 rows

# %%
#Compute total claim per customer
customers_clean.join(policies_clean,"customer_id").join(claims_clean,"policy_id").groupBy("customer_id").agg(sum("claim_amount")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th
# %%
city_df = customers_clean \
    .join(policies_clean, "customer_id") \
    .join(claims_clean, "policy_id", "left") \
    .groupBy("city") \
    .agg(
        sum("premium").alias("city_total_premium"),
        sum("claim_amount").alias("city_total_claim")
    )

city_df.show()
# Out:
# +---------+------------------+----------------+
# |     city|city_total_premium|city_total_claim|
# +---------+------------------+----------------+
# |Hyderabad|            133324|           74711|
# |Bangalore|            204635|          103231|
# |  Chennai|            161340|          132298|
# |   Mumbai|            160517|           26767|
# +---------+------------------+----------------+

# %% [markdown]
# ### Advanced sql

# %%
customers_clean.createOrReplaceTempView("customers")
policies_clean.createOrReplaceTempView("policies")
claims_clean.createOrReplaceTempView("claims")
agents_clean.createOrReplaceTempView("agents")
policy_agent_clean.createOrReplaceTempView("policy_agent")

# %%
result = spark.sql("""
WITH premium_cte AS (
    SELECT 
        customer_id,
        SUM(premium) AS total_premium
    FROM policies
    GROUP BY customer_id
),

claims_cte AS (
    SELECT 
        p.customer_id,
        SUM(c.claim_amount) AS total_claims
    FROM claims c
    JOIN policies p ON c.policy_id = p.policy_id
    GROUP BY p.customer_id
),

risk_cte AS (
    SELECT 
        c.customer_id,
        c.city,
        COALESCE(cl.total_claims, 0) AS total_claims,
        COALESCE(pr.total_premium, 0) AS total_premium,
        CASE 
            WHEN pr.total_premium = 0 THEN 0
            ELSE cl.total_claims / pr.total_premium
        END AS risk_score
    FROM customers c
    LEFT JOIN premium_cte pr ON c.customer_id = pr.customer_id
    LEFT JOIN claims_cte cl ON c.customer_id = cl.customer_id
),

rank_cte AS (
    SELECT *,
           ROW_NUMBER() OVER (PARTITION BY city ORDER BY risk_score DESC) AS rank
    FROM risk_cte
)

SELECT *
FROM rank_cte
WHERE rank <= 3
""")

display(result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>city</th><th>total_claims</th><th>total_premium</th><th>risk_score</th><th>rank</th></tr></thead><tbody><tr><td>58</td><td>Bangalore</td><td>10908</td><td>2618</td><td>4.166539343009931</td><td>1</td></tr><tr><td>1</td><td>Bangalore</td><td>29747</td><td>17437</td><td>1.7059700636577393</td><td>2</td></tr><tr><td>47</td><td>Bangalore</td><td>26647</td><td>16608</td><td>1.6044677263969171</td><td>3</td></tr><tr><td>54</td><td>Chennai</td><td>23605</td><td>2962</td><td>7.969277515192437</td><td>1</td></tr><tr><td>21</td><td>Chennai</td><td>17993</td><td>6560</td><td>2.7428353658536584</td><td>2</td></tr><tr><td>56</td><td>Chennai</td><td>28118</td><td>13140</td><td>2.1398782343987826</td><td>3</td></tr><tr><td>46</td><td>Hyderabad</td><td>7373</td><td>378</td><td>19.505291005291006</td><td>1</td></tr><tr><td>19</td><td>Hyderabad</td><td>36814</td><td>17219</td><td>2.1379871072652303</td><td>2</td></tr><tr><td>4</td><td>Hyderabad</td><td>23940</td><td>16719</td><td>1.4319038219989233</td><td>3</td></tr><tr><td>14</td><td>Mumbai</td><td>7541</td><td>16596</td><td>0.45438659918052543</td><td>1</td></tr><tr><td>18</td><td>Mumbai</td><td>16999</td><td>39181</td><td>0.4338582476200199</td><td>2</td></tr><tr><td>48</td><td>Mumbai</td><td>2227</td><td>14425</td><td>0.1543847487001733</td><td>3</td></tr></tbody></table></div>

# %%
result = spark.sql("""
WITH agent_premium AS (
    SELECT 
        pa.agent_id,
        a.name,
        a.region,
        SUM(p.premium) AS total_premium
    FROM policy_agent pa
    JOIN policies p ON pa.policy_id = p.policy_id
    JOIN agents a ON pa.agent_id = a.agent_id
    GROUP BY pa.agent_id, a.name, a.region
)

SELECT *,
       ROW_NUMBER() OVER (ORDER BY total_premium DESC) AS row_num,
       RANK() OVER (ORDER BY total_premium DESC) AS rank,
       DENSE_RANK() OVER (ORDER BY total_premium DESC) AS dense_rank
FROM agent_premium
""")

display(result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>agent_id</th><th>name</th><th>region</th><th>total_premium</th><th>row_num</th><th>rank</th><th>dense_rank</th></tr></thead><tbody><tr><td>10</td><td>Agent10</td><td>North</td><td>45739</td><td>1</td><td>1</td><td>1</td></tr><tr><td>14</td><td>Agent14</td><td>East</td><td>39351</td><td>2</td><td>2</td><td>2</td></tr><tr><td>15</td><td>Agent15</td><td>North</td><td>37619</td><td>3</td><td>3</td><td>3</td></tr><tr><td>20</td><td>Agent20</td><td>North</td><td>34621</td><td>4</td><td>4</td><td>4</td></tr><tr><td>13</td><td>Agent13</td><td>South</td><td>32499</td><td>5</td><td>5</td><td>5</td></tr><tr><td>1</td><td>Agent1</td><td>South</td><td>31473</td><td>6</td><td>6</td><td>6</td></tr><tr><td>7</td><td>Agent7</td><td>South</td><td>30257</td><td>7</td><td>7</td><td>7</td></tr><tr><td>11</td><td>Agent11</td><td>West</td><td>28463</td><td>8</td><td>8</td><td>8</td></tr><tr><td>12</td><td>Agent12</td><td>West</td><td>28395</td><td>9</td><td>9</td><td>9</td></tr><tr><td>8</td><td>Agent8</td><td>North</td><td>27553</td><td>10</td><td>10</td><td>10</td></tr><tr><td>3</td><td>Agent3</td><td>West</td><td>22332</td><td>11</td><td>11</td><td>11</td></tr><tr><td>2</td><td>Agent2</td><td>North</td><td>22154</td><td>12</td><td>12</td><td>12</td></tr><tr><td>4</td><td>Agent4</td><td>West</td><td>20788</td><td>13</td><td>13</td><td>13</td></tr><tr><td>19</td><td>Agent19</td><td>East</td><td>20644</td><td>14</td><td>14</td><td>14</td></tr><tr><td>9</td><td>Agent9</td><td>East</td><td>16770</td><td>15</td><td>15</td><td>15</td></tr><tr><td>16</td><td>Agent16</td><td>North</td><td>14704</td><td>16</td><td>16</td><td>16</td></tr><tr><td>5</td><td>Agent5</td><td>South</td><td>10166</td><td>17</td><td>17</td><td>17</td></tr><tr><td>18</td><td>Agent18</td><td>East</td><td>2812</td><td>18</td><td>18</td><td>18</td></tr><tr><td>6</td><td>Agent6</td><td>East</td><td>1509</td><td>19</td><td>19</td><td>19</td></tr></tbody></table></div>

# %%
final_df = customers_clean \
    .join(policies_clean, "customer_id", "inner") \
    .join(claims_clean, "policy_id", "left") \
    .join(policy_agent_clean, "policy_id", "left") \
    .join(agents_clean, "agent_id", "left")

final_df.show()
# Out:
# +--------+---------+-----------+------+---+---------+-----------+-------+----------+--------+------------+----------+--------+-------+------+
# |agent_id|policy_id|customer_id|  name|age|     city|policy_type|premium|start_date|claim_id|claim_amount|claim_date|  status|   name|region|
# +--------+---------+-----------+------+---+---------+-----------+-------+----------+--------+------------+----------+--------+-------+------+
# |      19|      174|          1| Cust1| 25|Bangalore|       Auto|  10181|2023-03-12|     212|       13997|2023-03-21| Pending|Agent19|  East|
# |      13|      166|          4| Cust4| 58|Hyderabad|     Health|  14924|2023-07-19|    NULL|        NULL|      NULL|    NULL|Agent13| South|
# |    NULL|      170|          1| Cust1| 25|Bangalore|       Life|   7256|2023-05-22|     269|        2023|2023-04-20| Pending|   NULL|  NULL|
# |    NULL|      127|          4| Cust4| 58|Hyderabad|     Health|   1795|2023-07-08|     231|       10296|2023-04-22|Rejected|   NULL|  NULL|
# |    NULL|      170|          1| Cust1| 25|Bangalore|       Life|   7256|2023-05-22|     209|        8158|2023-04-30| Pending|   NULL|  NULL|
# |    NULL|      127|          4| Cust4| 58|Hyderabad|     Health|   1795|2023-07-08|     228|       13644|2023-06-14|Approved|   NULL|  NULL|
# |    NULL|      170|          1| Cust1| 25|Bangalore|       Life|   7256|2023-05-22|     204|        5569|2023-02-15|Rejected|   NULL|  NULL|
# |       2|      174|          1| Cust1| 25|Bangalore|       Auto|  10181|2023-03-12|     212|       13997|2023-03-21| Pending| Agent2| North|
# |       7|      166|          4| Cust4| 58|Hyderabad|     Health|  14924|2023-07-19|    NULL|        NULL|      NULL|    NULL| Agent7| South|
# |       8|      150|          8| Cust8| 32|  Chennai|     Health|   9978|2023-06-24|     208|        5932|2023-05-22|Approved| Agent8| North|
# |      12|      110|          9| Cust9| 47|Hyderabad|       Life|  10514|2023-05-10|    NULL|        NULL|      NULL|    NULL|Agent12|  West|
# |       1|      177|         11|Cust11| 42|Hyderabad|       Auto|   5856|2023-03-13|    NULL|        NULL|      NULL|    NULL| Agent1| South|
# |      20|      151|         12|Cust12| 33|Bangalore|       Life|  15994|2023-01-09|     203|        6667|2023-02-05|Rejected|Agent20| North|
# |    NULL|      112|         14|Cust14| 60|   Mumbai|       Life|  16596|2023-10-23|     255|        1432|2023-10-08|Rejected|   NULL|  NULL|
# |       3|      116|         15|Cust15| 30|Hyderabad|       Auto|  11693|2023-08-18|    NULL|        NULL|      NULL|    NULL| Agent3|  West|
# |       5|      161|         11|Cust11| 42|Hyderabad|     Health|   9652|2023-02-20|     280|        2476|2023-06-27|Rejected| Agent5| South|
# |    NULL|      113|         12|Cust12| 33|Bangalore|       Auto|   9760|2023-10-28|    NULL|        NULL|      NULL|    NULL|   NULL|  NULL|
# |       4|      111|         11|Cust11| 42|Hyderabad|     Health|   6363|2023-02-20|    NULL|        NULL|      NULL|    NULL| Agent4|  West|
# |       8|      150|          8| Cust8| 32|  Chennai|     Health|   9978|2023-06-24|     206|        8459|2023-03-28|Rejected| Agent8| North|
# |    NULL|      112|         14|Cust14| 60|   Mumbai|       Life|  16596|2023-10-23|     219|        6109|2023-02-17| Pending|   NULL|  NULL|
# +--------+---------+-----------+------+---+---------+-----------+-------+----------+--------+------------+----------+--------+-------+------+
# only showing top 20 rows
